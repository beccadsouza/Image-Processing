# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from numpy import *
from cv2 import *
from google.colab.patches import *
from warnings import *


filterwarnings('ignore')
# Reading image and storing it in memory
image = imread('/content/drive/My Drive/IP/Prac 2/image.jpg') 
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7F2A12FC4C50>

# %% [markdown]
# ## **Digital Negative**

# %%
# Subtract the img from max value(calculated from dtype)
neg_img = 255 - image
cv2_imshow(neg_img)
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7F2A12FD1DD8>

# %% [markdown]
# ## **Contrast Stretching: Min-Max Stretching**

# %%
from numpy import min, max

#Convert image to grayscale
img = cvtColor(image, COLOR_BGR2GRAY) 
# Create zeros array to store the stretched image
minmax_img = zeros((img.shape[0],img.shape[1]),dtype = 'uint8')
 
# Loop over the image and apply Min-Max formulae
for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        minmax_img[i,j] = 255*(img[i,j]-min(img))/(max(img)-min(img))
 
# Display the stretched image
cv2_imshow(minmax_img)
# Out:
# <PIL.Image.Image image mode=L size=400x300 at 0x7F2A1105D240>

# %% [markdown]
# ## **Thresholding**

# %%
# Convert image to grayscale
img = cvtColor(image, COLOR_BGR2GRAY) 

# Pixel intensity is greater than threshold value then value is truncated to threshold. Other values remain the same
ret, thresh1 = threshold(img, 120, 255, THRESH_TRUNC) 
# Pixel intensity is greater than threshold value then value is set to zero else value is set to 255
ret, thresh2 = threshold(img, 120, 255, THRESH_BINARY_INV) 
# Pixel intensity is greater than threshold value then value is set to 255 else value is set to zero
ret, thresh3 = threshold(img, 120, 255, THRESH_BINARY) 
 
cv2_imshow(thresh1) 
cv2_imshow(thresh2) 
cv2_imshow(thresh3)
# Out:
# <PIL.Image.Image image mode=L size=400x300 at 0x7F2A12FC4908>
# <PIL.Image.Image image mode=L size=400x300 at 0x7F2A12FC48D0>
# <PIL.Image.Image image mode=L size=400x300 at 0x7F2A12FC49E8>

# %% [markdown]
# ## **Gray Level Slicing**

# %%
# Convert image to grayscale
img = cvtColor(image, COLOR_BGR2GRAY) 

row, column = img.shape
# Create an zeros array to store the sliced image
gray_slice_img = zeros((row,column),dtype = 'uint8')

# Specify the min and max range
min_range = 10
max_range = 60

# Loop over the input image and if pixel value lies in desired range set it to 255 otherwise set it to 0.
for i in range(row):
    for j in range(column):
        if img[i,j]>min_range and img[i,j]<max_range:
            gray_slice_img[i,j] = 255
        else:
            gray_slice_img[i,j] = 0
# Display the image
cv2_imshow(gray_slice_img)
# Out:
# <PIL.Image.Image image mode=L size=400x300 at 0x7F2A12FDD4A8>

# %% [markdown]
# ## **Dynamic Range Compression: Log Transformation**

# %%
from numpy import max, log

img = image
# Apply log transform
log_img = (log(img+1)/(log(1+max(img))))*255
# Specify the data type
log_img = array(log_img,dtype=uint8)
cv2_imshow(log_img)
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7F2A12FDD2E8>

# %% [markdown]
# ## **Power Law Transformation: Gamma Correction**

# %%
for gamma in [0.1, 0.5, 1.2, 2.2]:
  # Apply Gamma valye on the normalised image and then multiply by scaling constant (For 8 bit, c=255)
  gamma_corrected = array(244*(image/255) ** gamma, dtype = 'uint8')
  print("Gamma = ", gamma)
  cv2_imshow(gamma_corrected)
# Out:
# Gamma =  0.1
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7F2A12FC4588>
# Gamma =  0.5
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7F2A12FC45F8>
# Gamma =  1.2
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7F2A12FC45F8>
# Gamma =  2.2
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7F2A12FC4780>

# %% [markdown]
# ## **Bit Plane Slicing**

# %%
# Convert image to grayscale
img = cvtColor(image, COLOR_BGR2GRAY)

lst = []
for i in range(img.shape[0]):
    for j in range(img.shape[1]):
         lst.append(binary_repr(img[i][j] ,width=8)) # width = no. of bits

# We have a list of strings where each string represents binary pixel value. To extract bit planes we need to iterate over the strings and store the characters corresponding to bit planes into lists.
# Multiply with 2^(n-1) and reshape to reconstruct the bit image.
eight_bit_img = (array([int(i[0]) for i in lst],dtype = uint8) * 128).reshape(img.shape[0],img.shape[1])
seven_bit_img = (array([int(i[1]) for i in lst],dtype = uint8) * 64).reshape(img.shape[0],img.shape[1])
six_bit_img = (array([int(i[2]) for i in lst],dtype = uint8) * 32).reshape(img.shape[0],img.shape[1])
five_bit_img = (array([int(i[3]) for i in lst],dtype = uint8) * 16).reshape(img.shape[0],img.shape[1])
four_bit_img = (array([int(i[4]) for i in lst],dtype = uint8) * 8).reshape(img.shape[0],img.shape[1])
three_bit_img = (array([int(i[5]) for i in lst],dtype = uint8) * 4).reshape(img.shape[0],img.shape[1])
two_bit_img = (array([int(i[6]) for i in lst],dtype = uint8) * 2).reshape(img.shape[0],img.shape[1])
one_bit_img = (array([int(i[7]) for i in lst],dtype = uint8) * 1).reshape(img.shape[0],img.shape[1])

#Concatenate these images for ease of display using cv2.hconcat()
finalr = hconcat([eight_bit_img,seven_bit_img,six_bit_img,five_bit_img])
finalv = hconcat([four_bit_img,three_bit_img,two_bit_img,one_bit_img])

# Vertically concatenate
final = vconcat([finalr,finalv])

# Display the images
cv2_imshow(final)
# Out:
# <PIL.Image.Image image mode=L size=1600x600 at 0x7F2A12FC4C50>

# %%
img = image
watermark = imread('/content/drive/My Drive/IP/Prac 2/watermark.png') 
cv2_imshow(watermark)
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7F2A11054160>

# %%
resized_watermark = resize(watermark,(400,300))
watermarked_img = (0.6* img) +  (0.4 * resized_watermark)
cv2_imshow(watermarked_img)
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7F2A11062320>
